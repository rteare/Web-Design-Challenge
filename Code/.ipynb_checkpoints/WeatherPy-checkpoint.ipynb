# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 627

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Create URL for API
base_url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"
query_url = f"{base_url}appid={weather_api_key}&units={units}&q="

# %%
# List for holding data
city_list = []
lat_list = []
lng_list = []
maxtemp_list = []
humidity_list = []
cloudiness_list = []
windspeed_list = []
country_list = []
date_list = []
index_count = 0
set_count = 1

# %%
# Print the list header
print("Beginning Data Retrieval ")
print("-----------------------------")

# Loop through for weather data for cities
for index, city in enumerate(cities, start = 1):
    
    response = requests.get(query_url + city).json()
    
    try:
        city_list.append(response["name"])
        lat_list.append(response["coord"]["lat"])
        lng_list.append(response["coord"]["lon"])
        maxtemp_list.append(response['main']['temp_max'])
        humidity_list.append(response["main"]["humidity"])
        cloudiness_list.append(response["clouds"]["all"])
        windspeed_list.append(response["wind"]["speed"])
        country_list.append(response["sys"]["country"])
        date_list.append(response["dt"])
        
        # Start new set when it hits 50
        if index_count > 49:
            index_count = 0
            set_count = set_count + 1
    
        else:
            index_count = index_count + 1
            
        # Format for printing the list of cities
        print(f"Processing Record {index_count} of Set {set_count} | {city}") 
  
    # Catch for the cities that dont have data in API
    except(KeyError, IndexError):
        print("City not found. Skipping...")

print("-----------------------------")
print("Data Retrieval Complete")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | upernavik
# City not found. Skipping...
# Processing Record 2 of Set 1 | steamboat springs
# Processing Record 3 of Set 1 | buturlinovka
# Processing Record 4 of Set 1 | ternate
# Processing Record 5 of Set 1 | busselton
# Processing Record 6 of Set 1 | mnogovershinnyy
# Processing Record 7 of Set 1 | honjo
# Processing Record 8 of Set 1 | chatellerault
# Processing Record 9 of Set 1 | hobart
# Processing Record 10 of Set 1 | port elizabeth
# Processing Record 11 of Set 1 | kobryn
# Processing Record 12 of Set 1 | hovd
# Processing Record 13 of Set 1 | lagoa
# Processing Record 14 of Set 1 | naze
# Processing Record 15 of Set 1 | rikitea
# City not found. Skipping...
# Processing Record 16 of Set 1 | castro
# City not found. Skipping...
# Processing Record 17 of Set 1 | ushuaia
# Processing Record 18 of Set 1 | cabo san lucas
# City not found. Skipping...
# Processing Record 19 of Set 1 | bandarbeyla
# Processing Record 20 of Set 1 | roebourne
# Processing Record 21 of Set 1 | port alfred
# City not found. Skipping...
# Processing Record 22 of Set 1 | narsaq
# Processing Record 23 of Set 1 | puerto ayora
# Processing Record 24 of Set 1 | geraldton
# Processing Record 25 of Set 1 | hamilton
# Processing Record 26 of Set 1 | selma
# Processing Record 27 of Set 1 | mitu
# Processing Record 28 of Set 1 | new norfolk
# Processing Record 29 of Set 1 | buenos aires
# Processing Record 30 of Set 1 | yantzaza
# Processing Record 31 of Set 1 | jamestown
# Processing Record 32 of Set 1 | butaritari
# Processing Record 33 of Set 1 | arraial do cabo
# Processing Record 34 of Set 1 | dikson
# Processing Record 35 of Set 1 | tuktoyaktuk
# Processing Record 36 of Set 1 | caravelas
# Processing Record 37 of Set 1 | half moon bay
# City not found. Skipping...
# Processing Record 38 of Set 1 | sistranda
# Processing Record 39 of Set 1 | carnarvon
# Processing Record 40 of Set 1 | manggar
# Processing Record 41 of Set 1 | sorland
# Processing Record 42 of Set 1 | avarua
# Processing Record 43 of Set 1 | vaini
# Processing Record 44 of Set 1 | garissa
# Processing Record 45 of Set 1 | khatanga
# Processing Record 46 of Set 1 | kirksville
# Processing Record 47 of Set 1 | tura
# Processing Record 48 of Set 1 | mataura
# Processing Record 49 of Set 1 | san andres
# Processing Record 50 of Set 1 | vacaria
# Processing Record 0 of Set 2 | haines junction
# Processing Record 1 of Set 2 | alofi
# Processing Record 41 of Set 4 | east london
# Processing Record 42 of Set 4 | beringovskiy
# Processing Record 43 of Set 4 | hasaki
# Processing Record 44 of Set 4 | lagoa santa
# City not found. Skipping...
# Processing Record 45 of Set 4 | shar
# Processing Record 46 of Set 4 | touros
# Processing Record 47 of Set 4 | cape town
# Processing Record 48 of Set 4 | luanda
# Processing Record 49 of Set 4 | beyneu
# Processing Record 50 of Set 4 | roald
# Processing Record 0 of Set 5 | hualmay
# Processing Record 1 of Set 5 | trelew
# Processing Record 2 of Set 5 | saskylakh
# Processing Record 3 of Set 5 | jutai
# Processing Record 4 of Set 5 | ust-barguzin
# Processing Record 5 of Set 5 | monchegorsk
# Processing Record 6 of Set 5 | chino valley
# Processing Record 7 of Set 5 | airai
# Processing Record 8 of Set 5 | usinsk
# Processing Record 9 of Set 5 | wenling
# Processing Record 10 of Set 5 | nantucket
# Processing Record 11 of Set 5 | dodge city
# Processing Record 12 of Set 5 | eregli
# Processing Record 13 of Set 5 | lasa
# Processing Record 14 of Set 5 | birao
# Processing Record 15 of Set 5 | port blair
# City not found. Skipping...
# Processing Record 16 of Set 5 | kavaratti
# Processing Record 17 of Set 5 | surman
# Processing Record 18 of Set 5 | flinders
# Processing Record 19 of Set 5 | dinagat
# Processing Record 20 of Set 5 | tanout
# Processing Record 21 of Set 5 | dingle
# Processing Record 22 of Set 5 | morehead
# Processing Record 23 of Set 5 | padang
# Processing Record 24 of Set 5 | urumqi
# Processing Record 25 of Set 5 | tymovskoye
# Processing Record 26 of Set 5 | petatlan
# Processing Record 27 of Set 5 | angoche
# City not found. Skipping...
# Processing Record 28 of Set 5 | polovinnoye
# Processing Record 29 of Set 5 | derzhavinsk
# Processing Record 30 of Set 5 | diffa
# Processing Record 31 of Set 5 | bengkulu
# Processing Record 32 of Set 5 | surt
# Processing Record 33 of Set 5 | nikolskoye
# City not found. Skipping...
# Processing Record 34 of Set 5 | kloulklubed
# Processing Record 35 of Set 5 | tando muhammad khan
# Processing Record 36 of Set 5 | baoqing
# Processing Record 37 of Set 5 | dunedin
# Processing Record 38 of Set 5 | gornopravdinsk
# Processing Record 39 of Set 5 | vanimo
# Processing Record 40 of Set 5 | kaitangata
# Processing Record 41 of Set 5 | cuamba
# Processing Record 42 of Set 5 | vardo
# Processing Record 43 of Set 5 | dir
# Processing Record 44 of Set 5 | strezhevoy
# Processing Record 45 of Set 5 | tiksi
# Processing Record 46 of Set 5 | najran
# Processing Record 47 of Set 5 | nelson bay
# Processing Record 48 of Set 5 | correntina
# Processing Record 49 of Set 5 | hohhot
# Processing Record 50 of Set 5 | madisonville
# Processing Record 0 of Set 6 | port hardy
# Processing Record 1 of Set 6 | shihezi
# Processing Record 2 of Set 6 | kruisfontein
# Processing Record 3 of Set 6 | yatou
# Processing Record 4 of Set 6 | boyolangu
# Processing Record 5 of Set 6 | husavik
# Processing Record 6 of Set 6 | virginia beach
# City not found. Skipping...
# Processing Record 7 of Set 6 | abu dhabi
# Processing Record 8 of Set 6 | ketchikan
# Processing Record 9 of Set 6 | korla
# Processing Record 10 of Set 6 | grand gaube
# Processing Record 11 of Set 6 | batemans bay
# Processing Record 12 of Set 6 | bathsheba
# Processing Record 13 of Set 6 | kon tum
# Processing Record 14 of Set 6 | merauke
# Processing Record 15 of Set 6 | laguna
# Processing Record 16 of Set 6 | leningradskiy
# Processing Record 17 of Set 6 | nemuro
# Processing Record 18 of Set 6 | adrar
# Processing Record 19 of Set 6 | corinto
# Processing Record 20 of Set 6 | bougouni
# Processing Record 21 of Set 6 | sao filipe
# Processing Record 22 of Set 6 | warnes
# Processing Record 23 of Set 6 | krasnoselkup
# Processing Record 24 of Set 6 | port moresby
# Processing Record 25 of Set 6 | yulara
# City not found. Skipping...
# Processing Record 26 of Set 6 | harlingen
# Processing Record 27 of Set 6 | kutum
# City not found. Skipping...
# Processing Record 28 of Set 6 | xuddur
# Processing Record 29 of Set 6 | college
# Processing Record 30 of Set 6 | shestakovo
# Processing Record 31 of Set 6 | doha
# Processing Record 32 of Set 6 | severo-kurilsk
# Processing Record 33 of Set 6 | souillac
# Processing Record 34 of Set 6 | dubai
# Processing Record 35 of Set 6 | eureka
# Processing Record 36 of Set 6 | poso
# Processing Record 37 of Set 6 | jequie
# Processing Record 38 of Set 6 | shingu
# Processing Record 39 of Set 6 | qaqortoq
# Processing Record 40 of Set 6 | torbay
# Processing Record 41 of Set 6 | mayor pablo lagerenza
# Processing Record 42 of Set 6 | dosso
# Processing Record 43 of Set 6 | samarai
# Processing Record 44 of Set 6 | lebu
# Processing Record 45 of Set 6 | mildura
# Processing Record 46 of Set 6 | broken hill
# Processing Record 47 of Set 6 | tromso
# Processing Record 48 of Set 6 | churapcha
# Processing Record 49 of Set 6 | guerrero negro
# Processing Record 50 of Set 6 | jalu
# Processing Record 0 of Set 7 | atuona
# Processing Record 1 of Set 7 | jiwani
# Processing Record 2 of Set 7 | lingao
# Processing Record 3 of Set 7 | havre
# Processing Record 4 of Set 7 | chililabombwe
# Processing Record 5 of Set 7 | mahon
# Processing Record 6 of Set 7 | san patricio
# Processing Record 7 of Set 7 | port victoria
# Processing Record 8 of Set 7 | srivardhan
# Processing Record 9 of Set 7 | iralaya
# Processing Record 10 of Set 7 | benghazi
# City not found. Skipping...
# Processing Record 11 of Set 7 | deputatskiy
# City not found. Skipping...
# Processing Record 12 of Set 7 | catamarca
# Processing Record 13 of Set 7 | saint anthony
# Processing Record 14 of Set 7 | itoman
# Processing Record 15 of Set 7 | sao gabriel da cachoeira
# Processing Record 16 of Set 7 | kaberamaido
# Processing Record 17 of Set 7 | adre
# Processing Record 18 of Set 7 | isangel
# Processing Record 19 of Set 7 | ponta delgada
# Processing Record 20 of Set 7 | vila do maio
# Processing Record 21 of Set 7 | veraval
# Processing Record 22 of Set 7 | san juan
# Processing Record 23 of Set 7 | xining
# Processing Record 24 of Set 7 | lieksa
# Processing Record 25 of Set 7 | ouallam
# Processing Record 26 of Set 7 | mvuma
# Processing Record 27 of Set 7 | kamsack
# Processing Record 28 of Set 7 | wagar
# Processing Record 29 of Set 7 | san quintin
# Processing Record 0 of Set 9 | marga
# Processing Record 1 of Set 9 | monterey
# Processing Record 2 of Set 9 | asau
# Processing Record 3 of Set 9 | maldonado
# Processing Record 4 of Set 9 | safaga
# Processing Record 5 of Set 9 | marsh harbour
# Processing Record 6 of Set 9 | herat
# Processing Record 7 of Set 9 | kirakira
# Processing Record 8 of Set 9 | ustrzyki dolne
# Processing Record 9 of Set 9 | moratuwa
# Processing Record 10 of Set 9 | athabasca
# Processing Record 11 of Set 9 | spokane
# Processing Record 12 of Set 9 | siparia
# Processing Record 13 of Set 9 | damghan
# Processing Record 14 of Set 9 | poum
# Processing Record 15 of Set 9 | oktyabrskoye
# Processing Record 16 of Set 9 | la ciotat
# Processing Record 17 of Set 9 | dudinka
# Processing Record 18 of Set 9 | desaguadero
# Processing Record 19 of Set 9 | cockburn town
# Processing Record 20 of Set 9 | el tigre
# Processing Record 21 of Set 9 | bonnyville
# Processing Record 22 of Set 9 | petrivka
# Processing Record 23 of Set 9 | shubarkuduk
# Processing Record 24 of Set 9 | santa barbara
# Processing Record 25 of Set 9 | bilma
# Processing Record 26 of Set 9 | meulaboh
# Processing Record 27 of Set 9 | abu kamal
# Processing Record 28 of Set 9 | sijunjung
# Processing Record 29 of Set 9 | palu
# Processing Record 30 of Set 9 | russell
# Processing Record 31 of Set 9 | clovis
# Processing Record 32 of Set 9 | vao
# Processing Record 33 of Set 9 | ginda
# Processing Record 34 of Set 9 | the pas
# Processing Record 35 of Set 9 | mocorito
# Processing Record 36 of Set 9 | namie
# Processing Record 37 of Set 9 | umm lajj
# City not found. Skipping...
# Processing Record 38 of Set 9 | ilhabela
# Processing Record 39 of Set 9 | shelburne
# Processing Record 40 of Set 9 | zhigansk
# Processing Record 41 of Set 9 | shu
# Processing Record 42 of Set 9 | gubkinskiy
# Processing Record 43 of Set 9 | carutapera
# Processing Record 44 of Set 9 | boca do acre
# Processing Record 45 of Set 9 | radviliskis
# Processing Record 46 of Set 9 | piacabucu
# Processing Record 47 of Set 9 | mareeba
# Processing Record 48 of Set 9 | hecun
# Processing Record 49 of Set 9 | talnakh
# City not found. Skipping...
# Processing Record 50 of Set 9 | stornoway
# Processing Record 0 of Set 10 | bundaberg
# Processing Record 1 of Set 10 | te anau
# City not found. Skipping...
# Processing Record 2 of Set 10 | saldanha
# Processing Record 3 of Set 10 | oktyabrskiy
# Processing Record 4 of Set 10 | namatanai
# Processing Record 5 of Set 10 | talgar
# Processing Record 6 of Set 10 | sao benedito do rio preto
# Processing Record 7 of Set 10 | parambu
# Processing Record 8 of Set 10 | takoradi
# Processing Record 9 of Set 10 | kasulu
# Processing Record 10 of Set 10 | fukue
# Processing Record 11 of Set 10 | miles city
# City not found. Skipping...
# Processing Record 12 of Set 10 | along
# Processing Record 13 of Set 10 | vestmannaeyjar
# Processing Record 14 of Set 10 | arlit
# Processing Record 15 of Set 10 | manoel urbano
# Processing Record 16 of Set 10 | erzin
# Processing Record 17 of Set 10 | neiafu
# Processing Record 18 of Set 10 | luza
# Processing Record 19 of Set 10 | chumikan
# Processing Record 20 of Set 10 | zyryanka
# Processing Record 21 of Set 10 | huadian
# Processing Record 22 of Set 10 | youghal
# Processing Record 23 of Set 10 | shahr-e babak
# Processing Record 24 of Set 10 | acapulco
# Processing Record 25 of Set 10 | kawalu
# Processing Record 26 of Set 10 | auki
# Processing Record 27 of Set 10 | morant bay
# Processing Record 28 of Set 10 | santa catalina
# Processing Record 29 of Set 10 | ludvika
# Processing Record 30 of Set 10 | norrtalje
# Processing Record 31 of Set 10 | ancud
# Processing Record 32 of Set 10 | muzhi
# City not found. Skipping...
# Processing Record 33 of Set 10 | sakaiminato
# Processing Record 34 of Set 10 | gat
# Processing Record 35 of Set 10 | prince rupert
# Processing Record 36 of Set 10 | yeppoon
# Processing Record 37 of Set 10 | heihe
# Processing Record 38 of Set 10 | pangody
# Processing Record 39 of Set 10 | pacific grove
# Processing Record 40 of Set 10 | tsabong
# City not found. Skipping...
# Processing Record 41 of Set 10 | tessalit
# Processing Record 42 of Set 10 | marawi
# Processing Record 43 of Set 10 | kevsala
# Processing Record 44 of Set 10 | kisaran
# Processing Record 45 of Set 10 | manacapuru
# Processing Record 46 of Set 10 | conde
# Processing Record 47 of Set 10 | khani
# Processing Record 48 of Set 10 | bethanien
# Processing Record 49 of Set 10 | varamin
# Processing Record 50 of Set 10 | moussoro
# Processing Record 0 of Set 11 | faya
# Processing Record 1 of Set 11 | northam
# Processing Record 2 of Set 11 | bilibino
# Processing Record 3 of Set 11 | lazarev
# Processing Record 4 of Set 11 | eenhana
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 5 of Set 11 | hulan ergi
# Processing Record 6 of Set 11 | high level
# Processing Record 7 of Set 11 | cidreira
# Processing Record 8 of Set 11 | havre-saint-pierre
# Processing Record 9 of Set 11 | shahdadkot
# Processing Record 10 of Set 11 | margate
# Processing Record 11 of Set 11 | hengyang
# Processing Record 12 of Set 11 | maniitsoq
# City not found. Skipping...
# Processing Record 13 of Set 11 | vostochnyy
# Processing Record 14 of Set 11 | vanavara
# Processing Record 15 of Set 11 | conakry
# Processing Record 16 of Set 11 | faridpur
# Processing Record 17 of Set 11 | smithers
# Processing Record 18 of Set 11 | medea
# Processing Record 19 of Set 11 | batagay-alyta
# Processing Record 20 of Set 11 | vanderhoof
# Processing Record 21 of Set 11 | halifax
# Processing Record 22 of Set 11 | takaka
# Processing Record 23 of Set 11 | antofagasta
# Processing Record 24 of Set 11 | lodja
# Processing Record 25 of Set 11 | huarmey
# Processing Record 26 of Set 11 | khasan
# Processing Record 27 of Set 11 | bayan
# Processing Record 28 of Set 11 | vaitape
# Processing Record 29 of Set 11 | mandalgovi
# City not found. Skipping...
# Processing Record 30 of Set 11 | hami
# Processing Record 31 of Set 11 | dandong
# Processing Record 32 of Set 11 | necochea
# Processing Record 33 of Set 11 | ambilobe
# Processing Record 34 of Set 11 | barra do garcas
# Processing Record 35 of Set 11 | kalemie
# Processing Record 36 of Set 11 | sagua de tanamo
# Processing Record 37 of Set 11 | bintulu
# Processing Record 38 of Set 11 | dutse
# Processing Record 39 of Set 11 | sao raimundo das mangabeiras
# Processing Record 40 of Set 11 | mandera
# Processing Record 41 of Set 11 | uyskoye
# Processing Record 42 of Set 11 | cairns
# Processing Record 43 of Set 11 | imbituba
# Processing Record 44 of Set 11 | emba
# Processing Record 45 of Set 11 | tabora
# Processing Record 46 of Set 11 | birjand
# Processing Record 47 of Set 11 | teahupoo
# Processing Record 48 of Set 11 | mezen
# Processing Record 49 of Set 11 | christchurch
# Processing Record 50 of Set 11 | luderitz
# Processing Record 0 of Set 12 | gosainganj
# Processing Record 1 of Set 12 | tucuma
# Processing Record 2 of Set 12 | mtwara
# Processing Record 3 of Set 12 | dong hoi
# Processing Record 4 of Set 12 | mandal
# Processing Record 5 of Set 12 | shenkursk
# Processing Record 6 of Set 12 | preeceville
# Processing Record 7 of Set 12 | haileybury
# Processing Record 8 of Set 12 | saint-joseph
# Processing Record 9 of Set 12 | bud
# Processing Record 10 of Set 12 | vestmanna
# Processing Record 11 of Set 12 | rogers
# Processing Record 12 of Set 12 | avare
# Processing Record 13 of Set 12 | shishou
# City not found. Skipping...
# Processing Record 14 of Set 12 | montecristi
# Processing Record 15 of Set 12 | campbellsville
# Processing Record 16 of Set 12 | shache
# Processing Record 17 of Set 12 | gwadar
# Processing Record 18 of Set 12 | mayumba
# City not found. Skipping...
# Processing Record 19 of Set 12 | pochutla
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Create a data frame of the API
weather_df = pd.DataFrame({'City': city_list, 'Lat': lat_list, 'Lng': lng_list, 'Max Temp': maxtemp_list,
                           'Humidity': humidity_list, 'Cloudiness': cloudiness_list, 'Wind Speed': windspeed_list,
                           'Country': country_list, 'Date': date_list})
weather_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Upernavik  72.7868  -56.1549     26.82        97          99
# 1  Steamboat Springs  40.4850 -106.8317     37.40        81          40
# 2       Buturlinovka  50.8239   40.6092     46.17        77          94
# 3            Ternate   0.8000  127.4000     85.98        65          22
# 4          Busselton -33.6500  115.3333     63.00        70          94
#
#    Wind Speed Country        Date
# 0        4.56      GL  1620790040
# 1        4.61      US  1620789941
# 2       11.86      RU  1620790041
# 3        2.82      ID  1620790041
# 4        4.00      AU  1620789756

# %%
# Save to  csv file
weather_df.to_csv("../output_data/cities.csv", encoding="utf-8", index = False)

# %%
# statistical data for the data frame
weather_df.describe()
# Out:
#               Lat         Lng    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  580.000000  580.000000  580.000000  580.000000  580.000000  580.000000
# mean    19.791129   17.001724   63.507879   68.493103   49.163793    7.130121
# std     32.583772   91.411973   16.875739   22.125290   39.205482    4.785481
# min    -54.800000 -179.166700   17.600000    7.000000    0.000000    0.220000
# 25%     -7.282650  -63.760300   51.982500   55.000000    6.750000    3.440000
# 50%     23.606850   21.750400   64.750000   73.000000   45.000000    6.070000
# 75%     46.446375   98.880500   77.947500   86.000000   90.000000    9.510000
# max     78.218600  179.316700   96.460000  100.000000  100.000000   25.080000
#
#                Date
# count  5.800000e+02
# mean   1.620790e+09
# std    7.936335e+01
# min    1.620790e+09
# 25%    1.620790e+09
# 50%    1.620790e+09
# 75%    1.620790e+09
# max    1.620790e+09

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#  Get the indices of cities that have humidity over 100%.
city_humidity_df = weather_df.loc[weather_df['Humidity'] > 100]
city_humidity_df

# No cites have humidity over 100%
# Out:
# Empty DataFrame
# Columns: [City, Lat, Lng, Max Temp, Humidity, Cloudiness, Wind Speed, Country, Date]
# Index: []

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
# Create scatter plot for Latitude vs. Temperature
plt.scatter(weather_df['Lat'], weather_df['Max Temp'], edgecolor = 'Black')
plt.title('City Latitude vs. Max Temperature (05/11/21)')
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.grid(linestyle = '-')

# Save Plot
plt.savefig('../output_data/lat_temp_plot')

# %% [markdown]
# Plot shows that temperatures lower as you move further from the equater.

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
# Create scatter plot for Latitude vs. Humidity
plt.scatter(weather_df['Lat'], weather_df['Humidity'], edgecolor = 'black')
plt.title('City Latitude vs. Humidity (05/11/21)')
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.grid(linestyle = '-')

# Save Plot
plt.savefig('../output_data/lat_humidity_plot')

# %% [markdown]
# There is no correlation for a cities latitude vs humidity.

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
# Create scatter plot for Latitude vs. Cloudiness
plt.scatter(weather_df['Lat'], weather_df['Cloudiness'], edgecolor = 'black')
plt.title('City Latitude vs. Cloudiness (05/11/21)')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.grid(linestyle = '-')

# Save Plot
plt.savefig('../output_data/lat_cloudiness_plot')

# %% [markdown]
# There is no correlation for a cities latitude vs cloudiness.

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
# Create scatter plot for Latitude vs. Wind Speed
plt.scatter(weather_df['Lat'], weather_df['Wind Speed'], edgecolor = 'black')
plt.title('City Latitude vs. Wind Speed (05/11/21)')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.grid(linestyle = '-')

# Save Plot
plt.savefig('../output_data/lat_windspeed_plot')

# %% [markdown]
# There is no correlation for a cities latitude vs windspeed. Most cities on 5/11/21 were below 15 mph.

# %% [markdown]
# ## Linear Regression

# %%
# Create Data Frame for Northern and Southern 
northern = weather_df.loc[weather_df['Lat'] >= 0, :]
southern = weather_df.loc[weather_df['Lat'] < 0, :]
# northern['Lat'].count()
# southern['Lat'].count()

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Linear Regression for Northern Hemisphere Max Temp vs. Latitude
x_values = northern['Lat']
y_values = northern['Max Temp']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = (x_values) * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot Capomulin data
plt.scatter(x_values, y_values)
plt.title('Northern Hemisphere Max Temp vs. Latitude')
plt.xlabel('Latitude')
plt.ylabel('Max Temp')

# Plot linear regression
plt.plot((x_values),regress_values,"r-")
plt.annotate(line_eq, (7,10), fontsize = 16, color = 'r')

# Print r-value
print(f"The r-value is: {rvalue}")

# Save Plot
plt.savefig('../output_data/north_maxtemp_lat_plot')
# Out:
# The r-value is: -0.8560773883402175

# %% [markdown]
# There is a very strong negative correlation between max temperature and latitude. As the cities move closers to the equater the temperatures are higher.

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Linear Regression for Southern Hemisphere Max Temp vs. Latitude
x_values = southern['Lat']
y_values = southern['Max Temp']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = (x_values) * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot Capomulin data
plt.scatter(x_values, y_values)
plt.title('Southern Hemisphere Max Temp vs. Latitude')
plt.xlabel('Latitude')
plt.ylabel('Max Temp')

# Plot linear regression
plt.plot((x_values),regress_values,"r-")
plt.annotate(line_eq, (-55,85), fontsize = 16, color = 'r')

# Print r-value
print(f"The r-value is: {rvalue}")

# Save Plot
plt.savefig('../output_data/south_maxtemp_lat_plot')
# Out:
# The r-value is: 0.6872255042012668

# %% [markdown]
# There is a strong positive correlation between max temperature and latitude. As the cities move closers to the equater the temperatures are higher.

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Linear Regression for Northern Hemisphere Humidity (%) vs. Latitude
x_values = northern['Lat']
y_values = northern['Humidity']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = (x_values) * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot Capomulin data
plt.scatter(x_values, y_values)
plt.title('Northern Hemisphere Humidity (%) vs. Latitude')
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')

# Plot linear regression
plt.plot((x_values),regress_values,"r-")
plt.annotate(line_eq, (40,10), fontsize = 16, color = 'r')

# Print r-value
print(f"The r-value is: {rvalue}")

# Save Plot
plt.savefig('../output_data/north_humidity_lat_plot')
# Out:
# The r-value is: 0.10138590824757124

# %% [markdown]
# There is a very weak positive correlation between humidity and the latitude of a city in the northern hemisphere. Which means there is no correlation.

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Linear Regression for Southern Hemisphere Humidity (%) vs. Latitude
x_values = southern['Lat']
y_values = southern['Humidity']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = (x_values) * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot Capomulin data
plt.scatter(x_values, y_values)
plt.title('Southern Hemisphere Humidity (%) vs. Latitude')
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')

# Plot linear regression
plt.plot((x_values),regress_values,"r-")
plt.annotate(line_eq, (-50,20), fontsize = 16, color = 'r')

# Print r-value
print(f"The r-value is: {rvalue}")

# Save Plot
plt.savefig('../output_data/south_humidity_lat_plot')
# Out:
# The r-value is: 0.27903200151787033

# %% [markdown]
# There is a very weak positive correlation between humidity and the latitude of a city in the southern hemisphere. Which means there is no correlation.

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Linear Regression for Northern Hemisphere Cloudiness (%) vs. Latitude
x_values = northern['Lat']
y_values = northern['Cloudiness']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = (x_values) * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot Capomulin data
plt.scatter(x_values, y_values)
plt.title('Northern Hemisphere Cloudiness (%) vs. Latitude')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')

# Plot linear regression
plt.plot((x_values),regress_values,"r-")
plt.annotate(line_eq, (40,10), fontsize = 16, color = 'r')

# Print r-value
print(f"The r-value is: {rvalue}")

# Save Plot
plt.savefig('../output_data/north_cloudiness_lat_plot')
# Out:
# The r-value is: 0.15910998950134544

# %% [markdown]
# There is a very weak positive correlation between cloudiness and the latitude of a city in the northern hemisphere. Which means there is no correlation.

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Linear Regression for Southern Hemisphere Cloudiness (%) vs. Latitude
x_values = southern['Lat']
y_values = southern['Cloudiness']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = (x_values) * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot Capomulin data
plt.scatter(x_values, y_values)
plt.title('Southern Hemisphere Cloudiness (%) vs. Latitude')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')

# Plot linear regression
plt.plot((x_values),regress_values,"r-")
plt.annotate(line_eq, (-55,50), fontsize = 16, color = 'r')

# Print r-value
print(f"The r-value is: {rvalue}")

# Save Plot
plt.savefig('../output_data/south_cloudiness_lat_plot')
# Out:
# The r-value is: 0.21731440403602736

# %% [markdown]
# There is a very weak positive correlation between cloudiness and the latitude of a city in the southern hemisphere. Which means there is no correlation.

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Linear Regression for Northern Hemisphere Cloudiness (%) vs. Latitude
x_values = northern['Lat']
y_values = northern['Wind Speed']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = (x_values) * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot Capomulin data
plt.scatter(x_values, y_values)
plt.title('Northern Hemisphere Wind Speed (mph) vs. Latitude')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')

# Plot linear regression
plt.plot((x_values),regress_values,"r-")
plt.annotate(line_eq, (40,25), fontsize = 16, color = 'r')

# Print r-value
print(f"The r-value is: {rvalue}")

# Save Plot
plt.savefig('../output_data/north_windspeed_lat_plot')
# Out:
# The r-value is: 0.0042348459932154015

# %% [markdown]
# There is no correlation between wind speed vs the cities latitude in the northern hemisphere

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Linear Regression for Southern Hemisphere Cloudiness (%) vs. Latitude
x_values = southern['Lat']
y_values = southern['Wind Speed']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = (x_values) * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot Capomulin data
plt.scatter(x_values, y_values)
plt.title('Southern Hemisphere Wind Speed (mph) vs. Latitude')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')

# Plot linear regression
plt.plot((x_values),regress_values,"r-")
plt.annotate(line_eq, (-50,20), fontsize = 16, color = 'r')

# Print r-value
print(f"The r-value is: {rvalue}")

# Save Plot
plt.savefig('../output_data/south_windspeed_lat_plot')
# Out:
# The r-value is: -0.09324804295356447

# %% [markdown]
# There is no correlation between wind speed vs the cities latitude in the southern hemisphere
